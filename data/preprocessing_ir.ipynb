# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_table('metadata.tsv')

# %%
df
# Out:
#                                    show_uri  \
# 0       spotify:show:2NYtxEZyYelR6RMKmjfPLB
# 1       spotify:show:15iWCbU7QoO23EndPEO6aN
# 2       spotify:show:6vZRgUFTYwbAA79UNCADr4
# 3       spotify:show:5BvKEjaMSuvUsGROGi2S7s
# 4       spotify:show:7w3h3umpH74veEJcbE6xf4
# ...                                     ...
# 105355  spotify:show:416U8ZhubKrFHq8ynOaxfH
# 105356  spotify:show:5rgmBAzsJ5znpV2b4WNDsb
# 105357  spotify:show:56CjYLQWyMx1MkOEQmlubi
# 105358  spotify:show:7uddSH8MhaK3Q6YFlllbVZ
# 105359  spotify:show:6r0bfT6lOLqDMh9ujnT1BW
#
#                                                 show_name  \
# 0                                    Kream in your Koffee
# 1                                   Morning Cup Of Murder
# 2       Inside The 18 : A Podcast for Goalkeepers by G...
# 3                                         Arrowhead Live!
# 4                                                   FBoL
# ...                                                   ...
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# show_uri
# show_name
# show_description
# publisher
# language
# rss_link
# episode_uri
# episode_name
# episode_description
# duration
# show_filename_prefix
# episode_filename_prefix

# %%
df[df['publisher'] == "Katie Houle"]
# Out:
#                                   show_uri             show_name  \
# 0      spotify:show:2NYtxEZyYelR6RMKmjfPLB  Kream in your Koffee
# 11957  spotify:show:2NYtxEZyYelR6RMKmjfPLB  Kream in your Koffee
# 46132  spotify:show:2NYtxEZyYelR6RMKmjfPLB  Kream in your Koffee
#
#                                         show_description    publisher  \
# 0      A 20-something blunt female takes on the world...  Katie Houle
# 11957  A 20-something blunt female takes on the world...  Katie Houle
# 46132  A 20-something blunt female takes on the world...  Katie Houle
#
#       language                                  rss_link  \
# 0       ['en']  https://anchor.fm/s/11b84b68/podcast/rss
# 11957   ['en']  https://anchor.fm/s/11b84b68/podcast/rss
# 46132   ['en']  https://anchor.fm/s/11b84b68/podcast/rss
#
#                                   episode_uri                 episode_name  \
# 0      spotify:episode:000A9sRBYdVh66csG2qEdj      1: It’s Christmas Time!
# ...

# %%
pd.unique(df['language'])
# Out:
# array(["['en']", "['en-US']", "['en-AU']", "['en-CA']", "['en-GB']",
#        "['en-NZ']", "['en-IE']", "['ms']", "['en-PH']", "['ta']",
#        "['en-ZA']", "['id']", "['nl-BE']", "['ga']", "['en-JM']",
#        "['hi']", "['ml']", "['en-IN']", "['es']", "['pt']"], dtype=object)

# %%
df[df['language'] == "['ta']"]
# Out:
#                                  show_uri                  show_name  \
# 1010  spotify:show:1zKopJDXQlxIIYedWgAfvr  Vetti Pechi Vidunja Pochi
#
#                                        show_description       publisher  \
# 1010  ungalin host - @ikvenkat vaarathuku oru murai ...  Koushik Venkat
#
#      language                                  rss_link  \
# 1010   ['ta']  https://anchor.fm/s/1219433c/podcast/rss
#
#                                  episode_uri                    episode_name  \
# 1010  spotify:episode:04dS8iVPCrxMbmRMpHyOJA  RJ Balaji is my Thalaivan DAW!
#
#                                     episode_description   duration  \
# 1010  #VPVP Episode 2 - In this episode, dha che pae...  10.445067
#
#              show_filename_prefix episode_filename_prefix
# 1010  show_1zKopJDXQlxIIYedWgAfvr  04dS8iVPCrxMbmRMpHyOJA

# %%
"""
TODO:  

Data Preprocessing:
- Remove all episodes that aren't English (have language that start with En)
- Combine all episodes of specific show
- Modify duration column to represent average duration of episode
- Combine episode descriptions
- Keeping Columns: show_uri, show_name, show_description, publisher, rss_link, episode_descriptions, avg_duration

Information Retrieval:

Assuming that both users enter publishers:

We want to create a TF-IDF matrix for podcast shows, which will be a m by n matrix where m is the number of podcasts and n is the number of words (from the combined episode descriptions)

For an individual user:
- Go through all of their preferred publishers:
    - For each preferred publisher, go through each publisher's shows and accumulate the respective TF-IDF vectors, average them to find individual preference

After having both preferred TF-IDF vectors both both users:
- Average the TF-IDF vectors for both users to get a TF-IDF vector that they would be likely to enjoy (1 by n vector)
- Calculate cosine similarity of average TF-IDF vector with podcast TF-IDF matrix (m by 1)
- Select top 10 based on cosine similarity
"""
# Out:
# HI
